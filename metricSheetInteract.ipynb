# %%
from get_ticker_info import fetch_financial_data, create_session
from authmodule import create_sheets_service, authenticate_google_drive
from drive_funcs import read_sheet_as_df
import pandas as pd

# %%
METRIC_SHEET_ID = "1lzVjg_2Kuhj21_Mmqj2pn-GfUXeBy7ieg-K7-v42dlQ"
METRIC_SHEET_YAHOO_RANGE = "yahoo"

drive_service = authenticate_google_drive(credspath="creds/oauth-creds.json")
sheets_service = create_sheets_service()
session = create_session()

# %%
df = read_sheet_as_df(
    sheets_service=sheets_service,
    spreadsheet_id=METRIC_SHEET_ID,
    range_name=METRIC_SHEET_YAHOO_RANGE,
)

# %%
df.head()
# Out:
#    TRUE rev (ttm) roa (ttm) roe (ttm) ebitda (s&p)    ev   div  \
# 0     A      None      None      None         None  None  None
# 1    AA      None      None      None         None  None  None
# 2  AAIC      None      None      None         None  None  None
# 3   AAL      None      None      None         None  None  None
# 4  AAME      None      None      None         None  None  None
#
#   cash, equiv & sti  debt   eps  ... retear/ mc revs/ debt mc/ ev    z"  \
# 0              None  None  None  ...       None       None   None  None
# 1              None  None  None  ...       None       None   None  None
# 2              None  None  None  ...       None       None   None  None
# 3              None  None  None  ...       None       None   None  None
# 4              None  None  None  ...       None       None   None  None
#
#   lev rk Placeholder for val1 Placeholder for val2 Placeholder for val3  \
# 0   None                 None                 None                 None
# ...

# %%
df_small = df.iloc[:20, :].copy()
df_small.shape
# Out:
# (20, 68)

# %%
df_small.head()
# Out:
#    TRUE rev (ttm) roa (ttm) roe (ttm) ebitda (s&p)    ev   div  \
# 0     A      None      None      None         None  None  None
# 1    AA      None      None      None         None  None  None
# 2  AAIC      None      None      None         None  None  None
# 3   AAL      None      None      None         None  None  None
# 4  AAME      None      None      None         None  None  None
#
#   cash, equiv & sti  debt   eps  ... retear/ mc revs/ debt mc/ ev    z"  \
# 0              None  None  None  ...       None       None   None  None
# 1              None  None  None  ...       None       None   None  None
# 2              None  None  None  ...       None       None   None  None
# 3              None  None  None  ...       None       None   None  None
# 4              None  None  None  ...       None       None   None  None
#
#   lev rk Placeholder for val1 Placeholder for val2 Placeholder for val3  \
# 0   None                 None                 None                 None
# ...

# %%
# Loop through each row of the DataFrame
def update_df(df):
    for index, row in df.iterrows():
        ticker = row["TRUE"]
        if pd.notna(ticker):  # Ensure the ticker is not NaN
            try:
                data = fetch_financial_data(ticker, session)
            except Exception as e:
                print(f"{ticker} ERROR: {e}")
                continue
            for key, value in data.items():
                if key in df.columns:
                    df.at[index, key] = value
    return df

# %%
updated_small = update_df(df_small)
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAIC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AAIC&crumb=MAxIHERH8cd
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABC&crumb=MAxIHERH8cd

# %%
updated_small.head()
# Out:
#    TRUE rev (ttm) roa (ttm) roe (ttm) ebitda (s&p)        ev   div  \
# 0     A   6591000     7.82%    20.71%      1612000  39599530  0.94
# 1    AA  10480000    -0.33%   -14.34%       564000  10002095   0.4
# 2  AAIC      None      None      None         None      None  None
# 3   AAL  53169000     3.51%      None      5925000  38364701  None
# 4  AAME    187521     0.37%    -0.70%         2698     56540  0.02
#
#   cash, equiv & sti      debt   eps  ... retear/ mc revs/ debt     mc/ ev  \
# 0           1590000   2726000  4.21  ...       0.02       2.42       0.98
# 1            944000   2600000 -3.76  ...      -0.18       4.03       0.71
# 2         Not Found      None  None  ...  No result  No result  No result
# 3           7578000  40059998  0.71  ...      -1.02       1.33       0.20
# 4            237592     40342 -0.05  ...       1.44       4.65       0.64
#
#      z" lev rk Placeholder for val1 Placeholder for val2 Placeholder for val3  \
# ...

# %%
whole_updated_df = update_df(df)
df.to_csv("updated_metrics.csv")
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AAIC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AAIC&crumb=MAxIHERH8cd
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABC&crumb=MAxIHERH8cd
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ACER?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ACER&crumb=MAxIHERH8cd
# ...

# %%
# now I need to actually upload this to the metric sheet programmatically
whole_updated_df.drop(columns="TRUE", inplace=True)

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError


# Function to update Google Sheet with DataFrame
def update_sheet(service, spreadsheet_id, range_name, df):
    # Convert DataFrame to list of lists
    values = [df.columns.tolist()] + df.values.tolist()

    body = {"values": values}

    try:
        result = (
            service.spreadsheets()
            .values()
            .update(
                spreadsheetId=spreadsheet_id,
                range=range_name,
                valueInputOption="RAW",
                body=body,
            )
            .execute()
        )
        print(f"{result.get('updatedCells')} cells updated.")
    except HttpError as err:
        print(err)


# Update the Google Sheet
update_sheet(sheets_service, METRIC_SHEET_ID, "testing123", whole_updated_df)
# Out:
# 266498 cells updated.

# %%
df.head()
# Out:
#   rev (ttm) roa (ttm) roe (ttm) ebitda (s&p)        ev   div  \
# 0   6591000     7.82%    20.71%      1612000  39599530  0.94
# 1  10480000    -0.33%   -14.34%       564000  10002095   0.4
# 2      None      None      None         None      None  None
# 3  53169000     3.51%      None      5925000  38364701  None
# 4    187521     0.37%    -0.70%         2698     56540  0.02
#
#   cash, equiv & sti      debt   eps       b  ... retear/ mc revs/ debt  \
# 0           1590000   2726000  4.21  21.311  ...       0.02       2.42
# 1            944000   2600000 -3.76  22.243  ...      -0.18       4.03
# 2         Not Found      None  None    None  ...  No result  No result
# 3           7578000  40059998  0.71  -8.384  ...      -1.02       1.33
# 4            237592     40342 -0.05   5.037  ...       1.44       4.65
#
#       mc/ ev    z" lev rk Placeholder for val1 Placeholder for val2  \
# 0       0.98  None   None                 None                 None
# ...

# %%
whole_updated_df.head()
# Out:
#   rev (ttm) roa (ttm) roe (ttm) ebitda (s&p)        ev   div  \
# 0   6591000     7.82%    20.71%      1612000  39599530  0.94
# 1  10480000    -0.33%   -14.34%       564000  10002095   0.4
# 2      None      None      None         None      None  None
# 3  53169000     3.51%      None      5925000  38364701  None
# 4    187521     0.37%    -0.70%         2698     56540  0.02
#
#   cash, equiv & sti      debt   eps       b  ... retear/ mc revs/ debt  \
# 0           1590000   2726000  4.21  21.311  ...       0.02       2.42
# 1            944000   2600000 -3.76  22.243  ...      -0.18       4.03
# 2         Not Found      None  None    None  ...  No result  No result
# 3           7578000  40059998  0.71  -8.384  ...      -1.02       1.33
# 4            237592     40342 -0.05   5.037  ...       1.44       4.65
#
#       mc/ ev    z" lev rk Placeholder for val1 Placeholder for val2  \
# 0       0.98  None   None                 None                 None
# ...

# %%
gme = pd.read_csv("gme.csv", index_col=0)
gme.head()
# Out:
#   Ticker  Revenue (ttm) Return on Assets (ttm) Return on Equity (ttm)  \
# 0    GME        4917500                 -0.78%                  1.93%
#
#    EBITDA (s&p)  Enterprise Value   Dividend  \
# 0         23800           7101297  No result
#
#    Cash, Equivalents, and Short-Term Investments  Total Debt  \
# 0                                        1082900      588700
#
#    Earnings Per Share  ...  Net Cash Flow to Price Ratio  \
# 0                0.08  ...                     No result
#
#    Dividend to Price Ratio  Cash to Price Ratio Net Cash to Price Ratio  \
# 0                No result                  0.1                    0.05
#
#   Net Net Working Capital to Price Ratio Asset to Price Ratio  \
# 0                              No result            No result
#
#   Retained Earnings to Market Capitalization Revenue to Debt Ratio  \
# 0                                  No result                  8.35
#
#   Market Capitalization to Enterprise Value Ratio Altman Z-Score
# ...

# %%
session = create_session()
gme = fetch_financial_data("GME", session)
gme
# Out:
# {'Ticker': 'GME',
#  'rev (ttm)': '4917500',
#  'roa (ttm)': '-0.53%',
#  'roe (ttm)': '1.93%',
#  'ebitda (s&p)': '35400',
#  'ev': '8447798',
#  'div': None,
#  'cash, equiv & sti': '1199300',
#  'debt': '588700',
#  'eps': 0.08,
#  'b': 4.269,
#  'lfcf (ttm)': '-271738',
#  'cfo (ttm)': '-210800',
#  'cfi (ttm)': '-33200',
#  'cff (ttm)': '-11600',
#  'tb': '1338600',
#  'pre-tx inc': '13100',
#  'inc tax exp': '5240',
#  'intrst exp': '26900',
#  'ebit': '-29700',
#  'capex': '-34900',
#  'curr assets': '1974200',
#  'cash': '1082900',
#  'shortterm investment': '277600',
#  'cur inventory': '632500',
#  'cur liab': '934500',
#  'net receivables': '91000',
#  'tot assets': '2709000',
#  'tot liab': '1370400',
#  'ret ear': '-212800',
#  '∆NWC ttm': '-55100',
#  'work cap': '1039700',
#  'eff tax rate': 0.4,
#  'tax shield': '10760',
#  'fcf': '-271738',
#  'ufcf': '167280',
#  'sfcf': '-168800',
#  'ncf': '-248500',
#  'ncash': '494200',
#  'Z1': '0.38',
#  'Z2': '-0.08',
# ...
